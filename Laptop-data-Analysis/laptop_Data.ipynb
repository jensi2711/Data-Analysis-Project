# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('laptop_data.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]>

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df['Ram'].unique()
# Out:
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '6GB', '32GB', '24GB', '64GB'],
#       dtype=object)

# %%
df['Ram']
# Out:
# 0        8GB
# 1        8GB
# 2        8GB
# 3       16GB
# 4        8GB
#         ...
# 1298     4GB
# 1299    16GB
# 1300     2GB
# 1301     6GB
# 1302     4GB
# Name: Ram, Length: 1303, dtype: object

# %%
df['Ram']=df['Ram'].str.replace('GB',' ')

# %%
df['Ram'].astype(int)
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: Ram, Length: 1303, dtype: int32

# %%
df['Weight'].unique()
# Out:
# array(['1.37kg', '1.34kg', '1.86kg', '1.83kg', '2.1kg', '2.04kg', '1.3kg',
#        '1.6kg', '2.2kg', '0.92kg', '1.22kg', '0.98kg', '2.5kg', '1.62kg',
#        '1.91kg', '2.3kg', '1.35kg', '1.88kg', '1.89kg', '1.65kg',
#        '2.71kg', '1.2kg', '1.44kg', '2.8kg', '2kg', '2.65kg', '2.77kg',
#        '3.2kg', '0.69kg', '1.49kg', '2.4kg', '2.13kg', '2.43kg', '1.7kg',
#        '1.4kg', '1.8kg', '1.9kg', '3kg', '1.252kg', '2.7kg', '2.02kg',
#        '1.63kg', '1.96kg', '1.21kg', '2.45kg', '1.25kg', '1.5kg',
#        '2.62kg', '1.38kg', '1.58kg', '1.85kg', '1.23kg', '1.26kg',
#        '2.16kg', '2.36kg', '2.05kg', '1.32kg', '1.75kg', '0.97kg',
#        '2.9kg', '2.56kg', '1.48kg', '1.74kg', '1.1kg', '1.56kg', '2.03kg',
#        '1.05kg', '4.4kg', '1.90kg', '1.29kg', '2.0kg', '1.95kg', '2.06kg',
#        '1.12kg', '1.42kg', '3.49kg', '3.35kg', '2.23kg', '4.42kg',
#        '2.69kg', '2.37kg', '4.7kg', '3.6kg', '2.08kg', '4.3kg', '1.68kg',
#        '1.41kg', '4.14kg', '2.18kg', '2.24kg', '2.67kg', '2.14kg',
#        '1.36kg', '2.25kg', '2.15kg', '2.19kg', '2.54kg', '3.42kg',
#        '1.28kg', '2.33kg', '1.45kg', '2.79kg', '1.84kg', '2.6kg',
#        '2.26kg', '3.25kg', '1.59kg', '1.13kg', '1.78kg', '1.10kg',
#        '1.15kg', '1.27kg', '1.43kg', '2.31kg', '1.16kg', '1.64kg',
#        '2.17kg', '1.47kg', '3.78kg', '1.79kg', '0.91kg', '1.99kg',
#        '4.33kg', '1.93kg', '1.87kg', '2.63kg', '3.4kg', '3.14kg',
#        '1.94kg', '1.24kg', '4.6kg', '4.5kg', '2.73kg', '1.39kg', '2.29kg',
#        '2.59kg', '2.94kg', '1.14kg', '3.8kg', '3.31kg', '1.09kg',
#        '3.21kg', '1.19kg', '1.98kg', '1.17kg', '4.36kg', '1.71kg',
#        '2.32kg', '4.2kg', '1.55kg', '0.81kg', '1.18kg', '2.72kg',
#        '1.31kg', '0.920kg', '3.74kg', '1.76kg', '1.54kg', '2.83kg',
#        '2.07kg', '2.38kg', '3.58kg', '1.08kg', '2.20kg', '2.75kg',
#        '1.70kg', '2.99kg', '1.11kg', '2.09kg', '4kg', '3.0kg', '0.99kg',
#        '3.52kg', '2.591kg', '2.21kg', '3.3kg', '2.191kg', '2.34kg',
#        '4.0kg'], dtype=object)

# %%
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df['Weight']=df['Weight'].astype(float)

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0] 
df['Y_res'] = new[1]

# %%
df['X_res']=df['X_res'].str.findall(r'\d+').apply(lambda x:x[0])

# %%
df['X_res']=df['X_res'].astype(int)
df['Y_res']=df['Y_res'].astype(int)

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# Touchscreen           int64
# IPS                   int64
# X_res                 int32
# Y_res                 int32
# dtype: object

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df['ppi']
# Out:
# 0       226.983005
# 1       127.677940
# 2       141.211998
# 3       220.534624
# 4       226.983005
#            ...
# 1298    157.350512
# 1299    276.053530
# 1300    111.935204
# 1301    100.454670
# 1302    100.454670
# Name: ppi, Length: 1303, dtype: float64

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu_Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df['Cpu_Name']
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1298         Intel Core i7
# 1299         Intel Core i7
# 1300    Intel Celeron Dual
# 1301         Intel Core i7
# 1302    Intel Celeron Dual
# Name: Cpu_Name, Length: 1303, dtype: object

# %%
def processor(text):
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Inte core i3':
        return text
    else:
         if text.split()[0]=='Intel':
             return 'other Intel Processor'
         else:
             return 'AMD Processor'

# %%
df['Cpu_Brand']=df['Cpu'].apply(processor)

# %%
df.drop(columns=['ScreenResolution','Inches','X_res','Y_res','Cpu'])
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook   8             128GB SSD
# 1      Apple           Ultrabook   8   128GB Flash Storage
# 2         HP            Notebook   8             256GB SSD
# 3      Apple           Ultrabook  16             512GB SSD
# 4      Apple           Ultrabook   8             256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible   4             128GB SSD
# 1299  Lenovo  2 in 1 Convertible  16             512GB SSD
# 1300  Lenovo            Notebook   2    64GB Flash Storage
# 1301      HP            Notebook   6               1TB HDD
# 1302    Asus            Notebook   4             500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# 3               AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300             Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302             Intel HD Graphics  Windows 10    2.20   19660.3200
#
#       Touchscreen  IPS         ppi            Cpu_Name              Cpu_Brand
# 0               0    1  226.983005       Intel Core i5  other Intel Processor
# 1               0    0  127.677940       Intel Core i5  other Intel Processor
# 2               0    0  141.211998       Intel Core i5  other Intel Processor
# 3               0    1  220.534624       Intel Core i7  other Intel Processor
# 4               0    1  226.983005       Intel Core i5  other Intel Processor
# ...           ...  ...         ...                 ...                    ...
# 1298            1    1  157.350512       Intel Core i7  other Intel Processor
# 1299            1    1  276.053530       Intel Core i7  other Intel Processor
# 1300            0    0  111.935204  Intel Celeron Dual  other Intel Processor
# 1301            0    0  100.454670       Intel Core i7  other Intel Processor
# 1302            0    0  100.454670  Intel Celeron Dual  other Intel Processor
#
# [1303 rows x 13 columns]

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df2=df.copy()

# %%
df2['Memory']=df2['Memory'].str.replace('GB','')
df2['Memory']=df2['Memory'].str.replace('TB','000')

# %%
df2
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram             Memory  \
# 0                     Intel Core i5 2.3GHz   8             128 SSD
# 1                     Intel Core i5 1.8GHz   8   128 Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8             256 SSD
# 3                     Intel Core i7 2.7GHz  16             512 SSD
# 4                     Intel Core i5 3.1GHz   8             256 SSD
# ...                                    ...  ...                ...
# 1298            Intel Core i7 6500U 2.5GHz   4             128 SSD
# 1299            Intel Core i7 6500U 2.5GHz  16             512 SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2    64 Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6            1000 HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4             500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# 3               AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300             Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302             Intel HD Graphics  Windows 10    2.20   19660.3200
#
#       Touchscreen  IPS  X_res  Y_res         ppi            Cpu_Name  \
# 0               0    1   2560   1600  226.983005       Intel Core i5
# 1               0    0   1440    900  127.677940       Intel Core i5
# 2               0    0   1920   1080  141.211998       Intel Core i5
# 3               0    1   2880   1800  220.534624       Intel Core i7
# 4               0    1   2560   1600  226.983005       Intel Core i5
# ...           ...  ...    ...    ...         ...                 ...
# 1298            1    1   1920   1080  157.350512       Intel Core i7
# 1299            1    1   3200   1800  276.053530       Intel Core i7
# 1300            0    0   1366    768  111.935204  Intel Celeron Dual
# 1301            0    0   1366    768  100.454670       Intel Core i7
# 1302            0    0   1366    768  100.454670  Intel Celeron Dual
#
#                   Cpu_Brand
# 0     other Intel Processor
# 1     other Intel Processor
# 2     other Intel Processor
# 3     other Intel Processor
# 4     other Intel Processor
# ...                     ...
# 1298  other Intel Processor
# 1299  other Intel Processor
# 1300  other Intel Processor
# 1301  other Intel Processor
# 1302  other Intel Processor
#
# [1303 rows x 18 columns]

# %%
new=df2['Memory'].str.split('+',n=1,expand=True)

# %%
new
# Out:
#                       0     1
# 0               128 SSD  None
# 1     128 Flash Storage  None
# 2               256 SSD  None
# 3               512 SSD  None
# 4               256 SSD  None
# ...                 ...   ...
# 1298            128 SSD  None
# 1299            512 SSD  None
# 1300   64 Flash Storage  None
# 1301           1000 HDD  None
# 1302            500 HDD  None
#
# [1303 rows x 2 columns]

# %%
df2['First']=new[0]
df2['Second']=new[1]

# %%
df2['First']=df2['First'].str.strip()

# %%
df2["Layer1HDD"] = df2["First"].apply(lambda x: 1 if "HDD" in x else 0) 
df2["Layer1SSD"] = df2["First"].apply(lambda x: 1 if "SSD" in x else 0) 
df2["Layer1Hybrid"] = df2["First"].apply(lambda x: 1 if "Hybrid" in x else 0) 
df2["Layer1Flash_Storage"] = df2["First"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df2['First']=df2['First'].str.findall('\d+').str.get(0).astype(int)

# %%
df2["Second"].fillna("0", inplace = True)

# %%
df2["Layer2HDD"] = df2["Second"].apply(lambda x: 1 if "HDD" in x else 0) 
df2["Layer2SSD"] = df2["Second"].apply(lambda x: 1 if "SSD" in x else 0) 
df2["Layer2Hybrid"] = df2["Second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df2["Layer2Flash_Storage"] = df2["Second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df2['Second']=df2['Second'].str.findall('\d+').str.get(0).astype(int)

# %%
df2["HDD"]=(df2["First"]*df2["Layer1HDD"]+df2["Second"]*df2["Layer2HDD"]) 
df2["SSD"]=(df2["First"]*df2["Layer1SSD"]+df2["Second"]*df2["Layer2SSD"]) 
df2["Hybrid"]=(df2["First"]*df2["Layer1Hybrid"]+df2["Second"]*df2["Layer2Hybrid"] ) 
df2["Flash_Storage"]=(df2["First"]*df2["Layer1Flash_Storage"]+df2["Second"]*df2["Layer2Flash_Storage"])

# %%
df2.drop(columns=['First', 'Second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid','Layer1Flash_Storage','Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage','Memory'],inplace=True)

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df2.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Touchscreen         0
# IPS                 0
# X_res               0
# Y_res               0
# ppi                 0
# Cpu_Name            0
# Cpu_Brand           0
# HDD                 0
# SSD                 0
# Hybrid              0
# Flash_Storage       0
# dtype: int64

# %%
df2['Gpu brand'] = df2['Gpu'].apply(lambda x:x.split()[0])

# %%
df2['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df2 = df2[df2['Gpu brand'] != 'ARM']

# %%
df2['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
def osy(inp):  
       if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':       
          return 'Windows'    
       elif inp == 'macOS' or inp == 'Mac OS X':         
        return 'Mac'   
       else:       
        return 'Others/No OS/Linux'

# %%
df2['OS']=df2['OpSys'].apply(osy)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_14564\3774423830.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['OS']=df2['OpSys'].apply(osy)

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df2['Weight'],y=df2['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
X = df2.drop(columns=['Price'])
y = np.log(df2['Price'])

# %%
X,y
# Out:
# (     Company            TypeName  Inches  \
#  0      Apple           Ultrabook    13.3
#  1      Apple           Ultrabook    13.3
#  2         HP            Notebook    15.6
#  3      Apple           Ultrabook    15.4
#  4      Apple           Ultrabook    13.3
#  ...      ...                 ...     ...
#  1298  Lenovo  2 in 1 Convertible    14.0
#  1299  Lenovo  2 in 1 Convertible    13.3
#  1300  Lenovo            Notebook    14.0
#  1301      HP            Notebook    15.6
#  1302    Asus            Notebook    15.6
#
#                                  ScreenResolution  \
#  0             IPS Panel Retina Display 2560x1600
#  1                                       1440x900
#  2                              Full HD 1920x1080
#  3             IPS Panel Retina Display 2880x1800
#  4             IPS Panel Retina Display 2560x1600
#  ...                                          ...
#  1298   IPS Panel Full HD / Touchscreen 1920x1080
#  1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
#  1300                                    1366x768
#  1301                                    1366x768
#  1302                                    1366x768
#
#                                         Cpu  Ram                           Gpu  \
#  0                     Intel Core i5 2.3GHz   8   Intel Iris Plus Graphics 640
#  1                     Intel Core i5 1.8GHz   8         Intel HD Graphics 6000
#  2               Intel Core i5 7200U 2.5GHz   8          Intel HD Graphics 620
#  3                     Intel Core i7 2.7GHz  16             AMD Radeon Pro 455
#  4                     Intel Core i5 3.1GHz   8   Intel Iris Plus Graphics 650
#  ...                                    ...  ...                           ...
#  1298            Intel Core i7 6500U 2.5GHz   4          Intel HD Graphics 520
#  1299            Intel Core i7 6500U 2.5GHz  16          Intel HD Graphics 520
#  1300  Intel Celeron Dual Core N3050 1.6GHz   2              Intel HD Graphics
#  1301            Intel Core i7 6500U 2.5GHz   6             AMD Radeon R5 M330
#  1302  Intel Celeron Dual Core N3050 1.6GHz   4              Intel HD Graphics
#
#             OpSys  Weight  Touchscreen  ...  Y_res         ppi  \
#  0          macOS    1.37            0  ...   1600  226.983005
#  1          macOS    1.34            0  ...    900  127.677940
#  2          No OS    1.86            0  ...   1080  141.211998
#  3          macOS    1.83            0  ...   1800  220.534624
#  4          macOS    1.37            0  ...   1600  226.983005
#  ...          ...     ...          ...  ...    ...         ...
#  1298  Windows 10    1.80            1  ...   1080  157.350512
#  1299  Windows 10    1.30            1  ...   1800  276.053530
#  1300  Windows 10    1.50            0  ...    768  111.935204
#  1301  Windows 10    2.19            0  ...    768  100.454670
#  1302  Windows 10    2.20            0  ...    768  100.454670
#
#                  Cpu_Name              Cpu_Brand   HDD  SSD  Hybrid  \
#  0          Intel Core i5  other Intel Processor     0  128       0
#  1          Intel Core i5  other Intel Processor     0    0       0
#  2          Intel Core i5  other Intel Processor     0  256       0
#  3          Intel Core i7  other Intel Processor     0  512       0
#  4          Intel Core i5  other Intel Processor     0  256       0
#  ...                  ...                    ...   ...  ...     ...
#  1298       Intel Core i7  other Intel Processor     0  128       0
#  1299       Intel Core i7  other Intel Processor     0  512       0
#  1300  Intel Celeron Dual  other Intel Processor     0    0       0
#  1301       Intel Core i7  other Intel Processor  1000    0       0
#  1302  Intel Celeron Dual  other Intel Processor   500    0       0
#
#        Flash_Storage  Gpu brand                  OS
#  0                 0      Intel                 Mac
#  1               128      Intel                 Mac
#  2                 0      Intel  Others/No OS/Linux
#  3                 0        AMD                 Mac
#  4                 0      Intel                 Mac
#  ...             ...        ...                 ...
#  1298              0      Intel             Windows
#  1299              0      Intel             Windows
#  1300             64      Intel             Windows
#  1301              0        AMD             Windows
#  1302              0      Intel             Windows
#
#  [1302 rows x 22 columns],
#  0       11.175755
#  1       10.776777
#  2       10.329931
#  3       11.814476
#  4       11.473101
#            ...
#  1298    10.433899
#  1299    11.288115
#  1300     9.409283
#  1301    10.614129
#  1302     9.886358
#  Name: Price, Length: 1302, dtype: float64)

# %%
df2
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram                           Gpu  \
# 0                     Intel Core i5 2.3GHz   8   Intel Iris Plus Graphics 640
# 1                     Intel Core i5 1.8GHz   8         Intel HD Graphics 6000
# 2               Intel Core i5 7200U 2.5GHz   8          Intel HD Graphics 620
# 3                     Intel Core i7 2.7GHz  16             AMD Radeon Pro 455
# 4                     Intel Core i5 3.1GHz   8   Intel Iris Plus Graphics 650
# ...                                    ...  ...                           ...
# 1298            Intel Core i7 6500U 2.5GHz   4          Intel HD Graphics 520
# 1299            Intel Core i7 6500U 2.5GHz  16          Intel HD Graphics 520
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2              Intel HD Graphics
# 1301            Intel Core i7 6500U 2.5GHz   6             AMD Radeon R5 M330
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4              Intel HD Graphics
#
#            OpSys  Weight        Price  ...  Y_res         ppi  \
# 0          macOS    1.37   71378.6832  ...   1600  226.983005
# 1          macOS    1.34   47895.5232  ...    900  127.677940
# 2          No OS    1.86   30636.0000  ...   1080  141.211998
# 3          macOS    1.83  135195.3360  ...   1800  220.534624
# 4          macOS    1.37   96095.8080  ...   1600  226.983005
# ...          ...     ...          ...  ...    ...         ...
# 1298  Windows 10    1.80   33992.6400  ...   1080  157.350512
# 1299  Windows 10    1.30   79866.7200  ...   1800  276.053530
# 1300  Windows 10    1.50   12201.1200  ...    768  111.935204
# 1301  Windows 10    2.19   40705.9200  ...    768  100.454670
# 1302  Windows 10    2.20   19660.3200  ...    768  100.454670
#
#                 Cpu_Name              Cpu_Brand   HDD  SSD Hybrid  \
# 0          Intel Core i5  other Intel Processor     0  128      0
# 1          Intel Core i5  other Intel Processor     0    0      0
# 2          Intel Core i5  other Intel Processor     0  256      0
# 3          Intel Core i7  other Intel Processor     0  512      0
# 4          Intel Core i5  other Intel Processor     0  256      0
# ...                  ...                    ...   ...  ...    ...
# 1298       Intel Core i7  other Intel Processor     0  128      0
# 1299       Intel Core i7  other Intel Processor     0  512      0
# 1300  Intel Celeron Dual  other Intel Processor     0    0      0
# 1301       Intel Core i7  other Intel Processor  1000    0      0
# 1302  Intel Celeron Dual  other Intel Processor   500    0      0
#
#       Flash_Storage  Gpu brand                  OS
# 0                 0      Intel                 Mac
# 1               128      Intel                 Mac
# 2                 0      Intel  Others/No OS/Linux
# 3                 0        AMD                 Mac
# 4                 0      Intel                 Mac
# ...             ...        ...                 ...
# 1298              0      Intel             Windows
# 1299              0      Intel             Windows
# 1300             64      Intel             Windows
# 1301              0        AMD             Windows
# 1302              0      Intel             Windows
#
# [1302 rows x 23 columns]

# %%
df2
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram                           Gpu  \
# 0                     Intel Core i5 2.3GHz   8   Intel Iris Plus Graphics 640
# 1                     Intel Core i5 1.8GHz   8         Intel HD Graphics 6000
# 2               Intel Core i5 7200U 2.5GHz   8          Intel HD Graphics 620
# 3                     Intel Core i7 2.7GHz  16             AMD Radeon Pro 455
# 4                     Intel Core i5 3.1GHz   8   Intel Iris Plus Graphics 650
# ...                                    ...  ...                           ...
# 1298            Intel Core i7 6500U 2.5GHz   4          Intel HD Graphics 520
# 1299            Intel Core i7 6500U 2.5GHz  16          Intel HD Graphics 520
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2              Intel HD Graphics
# 1301            Intel Core i7 6500U 2.5GHz   6             AMD Radeon R5 M330
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4              Intel HD Graphics
#
#            OpSys  Weight        Price  ...  Y_res         ppi  \
# 0          macOS    1.37   71378.6832  ...   1600  226.983005
# 1          macOS    1.34   47895.5232  ...    900  127.677940
# 2          No OS    1.86   30636.0000  ...   1080  141.211998
# 3          macOS    1.83  135195.3360  ...   1800  220.534624
# 4          macOS    1.37   96095.8080  ...   1600  226.983005
# ...          ...     ...          ...  ...    ...         ...
# 1298  Windows 10    1.80   33992.6400  ...   1080  157.350512
# 1299  Windows 10    1.30   79866.7200  ...   1800  276.053530
# 1300  Windows 10    1.50   12201.1200  ...    768  111.935204
# 1301  Windows 10    2.19   40705.9200  ...    768  100.454670
# 1302  Windows 10    2.20   19660.3200  ...    768  100.454670
#
#                 Cpu_Name              Cpu_Brand   HDD  SSD Hybrid  \
# 0          Intel Core i5  other Intel Processor     0  128      0
# 1          Intel Core i5  other Intel Processor     0    0      0
# 2          Intel Core i5  other Intel Processor     0  256      0
# 3          Intel Core i7  other Intel Processor     0  512      0
# 4          Intel Core i5  other Intel Processor     0  256      0
# ...                  ...                    ...   ...  ...    ...
# 1298       Intel Core i7  other Intel Processor     0  128      0
# 1299       Intel Core i7  other Intel Processor     0  512      0
# 1300  Intel Celeron Dual  other Intel Processor     0    0      0
# 1301       Intel Core i7  other Intel Processor  1000    0      0
# 1302  Intel Celeron Dual  other Intel Processor   500    0      0
#
#       Flash_Storage  Gpu brand                  OS
# 0                 0      Intel                 Mac
# 1               128      Intel                 Mac
# 2                 0      Intel  Others/No OS/Linux
# 3                 0        AMD                 Mac
# 4                 0      Intel                 Mac
# ...             ...        ...                 ...
# 1298              0      Intel             Windows
# 1299              0      Intel             Windows
# 1300             64      Intel             Windows
# 1301              0        AMD             Windows
# 1302              0      Intel             Windows
#
# [1302 rows x 23 columns]

# %%
df2=df2.drop(columns=['Cpu','ScreenResolution','Gpu'])

# %%
df2['Ram']=df2['Ram'].astype(int)

# %%
df=df2.copy()

# %%
df2
# Out:
#      Company            TypeName  Inches  Ram       OpSys  Weight  \
# 0      Apple           Ultrabook    13.3    8       macOS    1.37
# 1      Apple           Ultrabook    13.3    8       macOS    1.34
# 2         HP            Notebook    15.6    8       No OS    1.86
# 3      Apple           Ultrabook    15.4   16       macOS    1.83
# 4      Apple           Ultrabook    13.3    8       macOS    1.37
# ...      ...                 ...     ...  ...         ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0    4  Windows 10    1.80
# 1299  Lenovo  2 in 1 Convertible    13.3   16  Windows 10    1.30
# 1300  Lenovo            Notebook    14.0    2  Windows 10    1.50
# 1301      HP            Notebook    15.6    6  Windows 10    2.19
# 1302    Asus            Notebook    15.6    4  Windows 10    2.20
#
#             Price  Touchscreen  IPS  X_res  Y_res         ppi  \
# 0      71378.6832            0    1   2560   1600  226.983005
# 1      47895.5232            0    0   1440    900  127.677940
# 2      30636.0000            0    0   1920   1080  141.211998
# 3     135195.3360            0    1   2880   1800  220.534624
# 4      96095.8080            0    1   2560   1600  226.983005
# ...           ...          ...  ...    ...    ...         ...
# 1298   33992.6400            1    1   1920   1080  157.350512
# 1299   79866.7200            1    1   3200   1800  276.053530
# 1300   12201.1200            0    0   1366    768  111.935204
# 1301   40705.9200            0    0   1366    768  100.454670
# 1302   19660.3200            0    0   1366    768  100.454670
#
#                 Cpu_Name              Cpu_Brand   HDD  SSD  Hybrid  \
# 0          Intel Core i5  other Intel Processor     0  128       0
# 1          Intel Core i5  other Intel Processor     0    0       0
# 2          Intel Core i5  other Intel Processor     0  256       0
# 3          Intel Core i7  other Intel Processor     0  512       0
# 4          Intel Core i5  other Intel Processor     0  256       0
# ...                  ...                    ...   ...  ...     ...
# 1298       Intel Core i7  other Intel Processor     0  128       0
# 1299       Intel Core i7  other Intel Processor     0  512       0
# 1300  Intel Celeron Dual  other Intel Processor     0    0       0
# 1301       Intel Core i7  other Intel Processor  1000    0       0
# 1302  Intel Celeron Dual  other Intel Processor   500    0       0
#
#       Flash_Storage Gpu brand                  OS
# 0                 0     Intel                 Mac
# 1               128     Intel                 Mac
# 2                 0     Intel  Others/No OS/Linux
# 3                 0       AMD                 Mac
# 4                 0     Intel                 Mac
# ...             ...       ...                 ...
# 1298              0     Intel             Windows
# 1299              0     Intel             Windows
# 1300             64     Intel             Windows
# 1301              0       AMD             Windows
# 1302              0     Intel             Windows
#
# [1302 rows x 20 columns]

# %%
df2.drop(columns=['X_res','Y_res'])
# Out:
#      Company            TypeName  Inches  Ram       OpSys  Weight  \
# 0      Apple           Ultrabook    13.3    8       macOS    1.37
# 1      Apple           Ultrabook    13.3    8       macOS    1.34
# 2         HP            Notebook    15.6    8       No OS    1.86
# 3      Apple           Ultrabook    15.4   16       macOS    1.83
# 4      Apple           Ultrabook    13.3    8       macOS    1.37
# ...      ...                 ...     ...  ...         ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0    4  Windows 10    1.80
# 1299  Lenovo  2 in 1 Convertible    13.3   16  Windows 10    1.30
# 1300  Lenovo            Notebook    14.0    2  Windows 10    1.50
# 1301      HP            Notebook    15.6    6  Windows 10    2.19
# 1302    Asus            Notebook    15.6    4  Windows 10    2.20
#
#             Price  Touchscreen  IPS         ppi            Cpu_Name  \
# 0      71378.6832            0    1  226.983005       Intel Core i5
# 1      47895.5232            0    0  127.677940       Intel Core i5
# 2      30636.0000            0    0  141.211998       Intel Core i5
# 3     135195.3360            0    1  220.534624       Intel Core i7
# 4      96095.8080            0    1  226.983005       Intel Core i5
# ...           ...          ...  ...         ...                 ...
# 1298   33992.6400            1    1  157.350512       Intel Core i7
# 1299   79866.7200            1    1  276.053530       Intel Core i7
# 1300   12201.1200            0    0  111.935204  Intel Celeron Dual
# 1301   40705.9200            0    0  100.454670       Intel Core i7
# 1302   19660.3200            0    0  100.454670  Intel Celeron Dual
#
#                   Cpu_Brand   HDD  SSD  Hybrid  Flash_Storage Gpu brand  \
# 0     other Intel Processor     0  128       0              0     Intel
# 1     other Intel Processor     0    0       0            128     Intel
# 2     other Intel Processor     0  256       0              0     Intel
# 3     other Intel Processor     0  512       0              0       AMD
# 4     other Intel Processor     0  256       0              0     Intel
# ...                     ...   ...  ...     ...            ...       ...
# 1298  other Intel Processor     0  128       0              0     Intel
# 1299  other Intel Processor     0  512       0              0     Intel
# 1300  other Intel Processor     0    0       0             64     Intel
# 1301  other Intel Processor  1000    0       0              0       AMD
# 1302  other Intel Processor   500    0       0              0     Intel
#
#                       OS
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# ...                  ...
# 1298             Windows
# 1299             Windows
# 1300             Windows
# 1301             Windows
# 1302             Windows
#
# [1302 rows x 18 columns]

# %%
df2.to_csv('clean.csv')
